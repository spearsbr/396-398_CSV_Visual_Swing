# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Swing_Trial.csv") # load the CSV file
df.head() # Displays the CSV files
# Out:
#   timestamp_ms\tqw\tqx\tqy\tqz\tgx\tgy\tgz
# 0                2373\t1\t0\t0\t0\t0\t0\t0
# 1                2395\t1\t0\t0\t0\t0\t0\t0
# 2                2417\t1\t0\t0\t0\t0\t0\t0
# 3                2439\t1\t0\t0\t0\t0\t0\t0
# 4                2462\t1\t0\t0\t0\t0\t0\t0

# %%
df['t'] = (df['timestamp_ms'] - df['timestamp_ms'].iloc[0]) / 1000.0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /root/miniconda3/envs/phenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp_ms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['t'] = (df['timestamp_ms'] - df['timestamp_ms'].iloc[0]) / 1000.0
#
# File /root/miniconda3/envs/phenv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /root/miniconda3/envs/phenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'timestamp_ms'

# %%
plt.figure(figsize=(10,4))
plt.plot(df['t'], df['gx'], label='gx')
plt.plot(df['t'], df['gy'], label='gy')
plt.plot(df['t'], df['gz'], label='gz')
plt.title("Gyroscope vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Angular Velocity (rad/s)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['t'], df['qw'], label='qw')
plt.plot(df['t'], df['qx'], label='qx')
plt.plot(df['t'], df['qy'], label='qy')
plt.plot(df['t'], df['qz'], label='qz')
plt.title("Quaternion Components vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
gyro = df[['gx','gy','gz']].values.astype(float)
gyro_mag = np.linalg.norm(gyro, axis=1)

plt.figure(figsize=(10,4))
plt.plot(df['t'], gyro_mag, color='purple')
plt.title("Overall Swing Motion (Gyro Magnitude)")
plt.xlabel("Time (s)")
plt.ylabel("Angular Speed (rad/s)")
plt.grid(True)
plt.show()
